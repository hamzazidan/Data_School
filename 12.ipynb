# %% [markdown]
# #### How do I use string methods in pandas?

# %%
import pandas as pd
import numpy as np

# %%
order = pd.read_table(r"http://bit.ly/chiporders")

# %%
order.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
order[order['item_name'].str.contains("Chicken")]
# Out:
#       order_id  quantity             item_name  \
# 4            2         2          Chicken Bowl
# 5            3         1          Chicken Bowl
# 11           6         1  Chicken Crispy Tacos
# 12           6         1    Chicken Soft Tacos
# 13           7         1          Chicken Bowl
# ...        ...       ...                   ...
# 4604      1828         1          Chicken Bowl
# 4615      1832         1    Chicken Soft Tacos
# 4619      1834         1    Chicken Salad Bowl
# 4620      1834         1    Chicken Salad Bowl
# 4621      1834         1    Chicken Salad Bowl
#
#                                      choice_description item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 11    [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $8.75
# 12    [Roasted Chili Corn Salsa, [Rice, Black Beans,...     $8.75
# ...

# %%
order.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
order['choice_description'].str.replace('[', '').str.replace(']', '')
order['choice_description'].str.replace(np.nan, "nothing")
# Out:
# /tmp/ipykernel_10334/556347930.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   order['choice_description'].str.replace('[', '').str.replace(']', '')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /media/hamza/Zeidan/Data_school/12.ipynb Cell 7 line 2
#       <a href='vscode-notebook-cell:/media/hamza/Zeidan/Data_school/12.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> order['choice_description'].str.replace('[', '').str.replace(']', '')
# ----> <a href='vscode-notebook-cell:/media/hamza/Zeidan/Data_school/12.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> order['choice_description'].str.replace(np.nan, "nothing")
#
# ...
